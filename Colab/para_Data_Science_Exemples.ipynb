# %% [markdown]
# <a href="https://colab.research.google.com/github/Samuel442/Python/blob/main/Colab/para_Data_Science_Exemples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Escreva um código para instalar a versão 3.7.1 da biblioteca matplotlib.

# %%
# !pip install matplotlib==3.7.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.0/38.0 MB 26.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for matplotlib: filename=matplotlib-3.7.1-cp312-cp312-linux_x86_64.whl size=11092824 sha256=884d14b80ce4e0737adc1307d3be5fb8b4a132d3f302c27f5ad74fe1dc655799
#   Stored in directory: /root/.cache/pip/wheels/1c/06/fa/3453aac11411fac092c1bdfe52815f2f6969a42700d977e62f
# Successfully built matplotlib
# ...
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# arviz 0.22.0 requires matplotlib>=3.8, but you have matplotlib 3.7.1 which is incompatible.
# ...

# %% [markdown]
# 2. Escreva um código para importar a biblioteca numpy com o alias np.

# %%
# !pip install numpy
import numpy as np

# %% [markdown]
# 3. Crie um programa que leia a seguinte lista de números e escolha um número desta aleatoriamente.

# %% [markdown]
# lista = [8, 12, 54, 23, 43, 1, 90, 87, 105, 77]

# %%
import random

lista = [8, 12, 54, 23, 43, 1, 90, 87, 105, 77]

aleatorio = random.choice(lista)
print(aleatorio)
# Out:
# 8

# %% [markdown]
# 4. Crie um programa que sorteia, aleatoriamente, um número inteiro positivo menor que 100.

# %%
numero_inteiro_aleatorio = random.randint(1, 99)
print(f"Número inteiro: {numero_inteiro_aleatorio}")
# Out:
# Número inteiro: 81

# %% [markdown]
# 5. Crie um programa que solicite à pessoa usuária digitar dois números inteiros e calcular a potência do 1º número elevado ao 2º.

# %%
import math

numero_1 = int(input("Digite o primeiro número: "))
numero_2 = int(input("Digite o segundo número: "))

potencia = pow(numero_1, numero_2)
print("O resultado da potência é:", potencia)
# Out:
# Digite o primeiro número: 3
# Digite o segundo número: 2
# O resultado da potência é: 9

# %% [markdown]
# 6. Um programa deve ser escrito para sortear uma pessoa seguidora de uma rede social para ganhar um prêmio. A lista de participantes é numerada e devemos escolher aleatoriamente um número de acordo com a quantidade de participantes. Peça à pessoa usuária para fornecer o número de participantes do sorteio e devolva para ela o número sorteado.

# %%
participantes = int(input("Digite o número de participantes: "))

numero_sorteado = random.randint(1, participantes)
print("O número sorteado é:", numero_sorteado)
# Out:
# Digite o número de participantes: 1000
# O número sorteado é: 358

# %% [markdown]
# 7. Você recebeu uma demanda para gerar números de token para acessar o aplicativo de uma empresa. O token precisa ser par e variar de 1000 até 9998. Escreva um código que solicita à pessoa usuária o seu nome e exibe uma mensagem junto a esse token gerado aleatoriamente.

# %% [markdown]
# "Olá, [nome], o seu token de acesso é [token]! Seja bem-vindo(a)!"

# %%
import random

nome = input("Digite seu nome: ")
token = 0 # Inicializa a variável token

while True:
    token = random.randrange(1000, 10000) # randrange vai até 9999
    if token % 2 == 0:
        # Se for par, podemos parar o loop
        break

print(f"Olá, {nome}, o seu token de acesso é {token}! Seja bem-vindo(a)!")
# Out:
# Digite seu nome: b
# Olá, b, o seu token de acesso é 4628! Seja bem-vindo(a)!

# %% [markdown]
# 8. Para diversificar e atrair novos(as) clientes, uma lanchonete criou um item misterioso em seu cardápio chamado "salada de frutas surpresa". Neste item, são escolhidas aleatoriamente 3 frutas de uma lista de 12 para compor a salada de frutas da pessoa cliente. Crie o código que faça essa seleção aleatória de acordo com a lista abaixo:

# %% [markdown]
# frutas = ["maçã", "banana", "uva", "pêra",
#           "manga", "coco", "melancia", "mamão",
#           "laranja", "abacaxi", "kiwi", "ameixa"]

# %%
import random

frutas = ["maçã", "banana", "uva", "pêra",
          "manga", "coco", "melancia", "mamão",
          "laranja", "abacaxi", "kiwi", "ameixa"]

  # Seleciona 3 itens únicos da lista
itens_sorteados = random.sample(frutas, 3)

print(f"3 itens aleatórios: {itens_sorteados}")
# Out:
# 3 itens aleatórios: ['pêra', 'laranja', 'melancia']

# %% [markdown]
# 9. Você recebeu um desafio de calcular a raiz quadrada de uma lista de números, identificando quais resultaram em um número inteiro. A lista é a seguinte:

# %% [markdown]
# numeros = [2, 8, 15, 23, 91, 112, 256]

# %% [markdown]
# No final, informe quais números possuem raízes inteiras e seus respectivos valores.

# %% [markdown]
# Dica: use a comparação entre a divisão inteira (//) da raiz por 1 com o valor da raiz para verificar se o número é inteiro. Por exemplo:

# %%
import math

numeros = [2, 8, 15, 23, 91, 112, 256]

for numero in numeros:
    raiz = math.sqrt(numero)
    if raiz // 1 == raiz:
      print(f'{raiz} é inteiro')
# Out:
# 16.0 é inteiro

# %% [markdown]
# 10. Faça um programa para uma loja que vende grama para jardins. Essa loja trabalha com jardins circulares e o preço do metro quadrado da grama é de R$ 25,00. Peça à pessoa usuária o raio da área circular e devolva o valor em reais do quanto precisará pagar.

# %% [markdown]
# Dica: use a variável pi e o método pow() da biblioteca math. O cálculo da área de um círculo é de: A = π*r^2 (lê-se pi vezes raio ao quadrado).

# %% [markdown]
# Caso precise de ajuda, opções de solução das atividades estão disponíveis na seção “Opinião da pessoa instrutora”.

# %%
import math

metro_quadrado = 25

raio = float(input("Digite o raio da área circular: "))
area = math.pi * pow(raio,2)
preco_total = area * metro_quadrado
print(f"O preço total a pagar é de R$ {preco_total:.2f}")
# Out:
# Digite o raio da área circular: 2
# O preço total a pagar é de R$ 314.16
