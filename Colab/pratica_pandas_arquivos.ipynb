# %% [markdown]
# <a href="https://colab.research.google.com/github/Samuel442/Python/blob/main/Colab/pratica_pandas_arquivos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Chegou a hora de você testar os conhecimentos desenvolvidos durante a aula. Temos um arquivo no formato CSV, que foi obtido na página Informações de Saúde (TABNET) - DATASUS. Este arquivo contém os gastos hospitalares públicos de cada uma das Unidades da Federação brasileira no período de janeiro de 2008 a março de 2021.

# %% [markdown]
# Seu desafio aqui será fazer a leitura desse arquivo utilizando a função read_csv da biblioteca Pandas. Alguns parâmetros devem ser adicionados para que a leitura seja feita corretamente. Então, seguem algumas dicas:
#
# Verifique se o arquivo CSV está separado por vírgula ou ponto e vírgula.

# %%
import pandas as pd
import requests
import json

url = "https://raw.githubusercontent.com/alura-cursos/Pandas/main/dados_sus.csv"

dados_sus = pd.read_csv(
    url,
    encoding="ISO-8859-1",
    sep=";",
    skiprows=3,
    skipfooter=9,
    engine="python"
)

dados_sus
# Out:
#    Unidade da Federação      2008/Jan      2008/Fev      2008/Mar  \
# 0              Rondônia    1388528,39    2931283,42    1541682,52
# 1                  Acre     902416,00    1497206,26    1794028,48
# 2              Amazonas    4735529,42    7118990,57    8196635,49
# 3               Roraima     657889,53     777939,31     718688,03
# 4                  Pará   18864744,11   19553758,20   21937342,70
# 5                 Amapá    1120973,34    1268740,33     974651,24
# 6             Tocantins    3441592,69    4985688,85    6205612,60
# 7              Maranhão   10723506,39   13559679,41   13985142,36
# 8                 Piauí    7985142,43   10079928,25   10298372,45
# 9                 Ceará   15539821,90   25735101,55   28724625,75
# 10  Rio Grande do Norte    5947814,08    9509755,83   10352238,59
# 11              Paraíba   10723002,45   11386274,47   12053643,87
# 12           Pernambuco   14393949,89   24181400,95   29991302,71
# ...

# %%
https://docs.google.com/spreadsheets/d/1pvBoLyX8kP0TjtUbadVMGdTl4yzm6bHMThhPiqCVtpw/edit?usp=sharing
# Out:
#   File "/tmp/ipython-input-3789838571.py", line 1
#     https://docs.google.com/spreadsheets/d/1pvBoLyX8kP0TjtUbadVMGdTl4yzm6bHMThhPiqCVtpw/edit?usp=sharing
#                                            ^
# SyntaxError: invalid decimal literal

# %%
sheet_id = '1pvBoLyX8kP0TjtUbadVMGdTl4yzm6bHMThhPiqCVtpw'

# %%
url_csv_excel = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

# %%
dados_co2_sheets = pd.read_csv(url_csv_excel)

# %%
dados_co2_sheets.head()
# Out:
#        Country country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name           1990         1991  \
# 0  CO2 emissions (metric tons per capita)            NaN          NaN
# 1  CO2 emissions (metric tons per capita)    191.745.115  167.681.579
# 2  CO2 emissions (metric tons per capita)    553.661.955  544.538.649
# 3  CO2 emissions (metric tons per capita)  1.819.541.634  124.281.022
# 4  CO2 emissions (metric tons per capita)  7.521.831.658  723.537.924
#
#           1992           1993           1994           1995  ...  \
# 0          NaN            NaN            NaN            NaN  ...
# 1   95.957.742      8.472.111     75.545.827     68.467.956  ...
# ...

# %%
sheet_id = '1pvBoLyX8kP0TjtUbadVMGdTl4yzm6bHMThhPiqCVtpw'
sheet_name = 'CO2_emission'
url_co2 = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
co2_sheets = pd.read_csv(url_co2)

# %%
co2_sheets.head()
# Out:
#        Country country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name           1990         1991  \
# 0  CO2 emissions (metric tons per capita)            NaN          NaN
# 1  CO2 emissions (metric tons per capita)    191.745.115  167.681.579
# 2  CO2 emissions (metric tons per capita)    553.661.955  544.538.649
# 3  CO2 emissions (metric tons per capita)  1.819.541.634  124.281.022
# 4  CO2 emissions (metric tons per capita)  7.521.831.658  723.537.924
#
#           1992           1993           1994           1995  ...  \
# 0          NaN            NaN            NaN            NaN  ...
# 1   95.957.742      8.472.111     75.545.827     68.467.956  ...
# ...

# %%
sheet_id = '1pvBoLyX8kP0TjtUbadVMGdTl4yzm6bHMThhPiqCVtpw'
sheet_name = 'CopiadeCO2emission'
url_copia_co2 = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
copia_co2_sheets = pd.read_csv(url_copia_co2)

# %%
copia_co2_sheets.head()
# Out:
#        Country country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name           1990         1991  \
# 0  CO2 emissions (metric tons per capita)            NaN          NaN
# 1  CO2 emissions (metric tons per capita)    191.745.115  167.681.579
# 2  CO2 emissions (metric tons per capita)    553.661.955  544.538.649
# 3  CO2 emissions (metric tons per capita)  1.819.541.634  124.281.022
# 4  CO2 emissions (metric tons per capita)  7.521.831.658  723.537.924
#
#           1992           1993           1994           1995  ...  \
# 0          NaN            NaN            NaN            NaN  ...
# 1   95.957.742      8.472.111     75.545.827     68.467.956  ...
# ...

# %%
copia_co2_sheets.to_csv('dados_emissoes_co2.csv', index=False)
co2_sheets.to_csv('copia_dados_emissoes_co2.csv', index=False)

# %%
dados_usuarios = requests.get('https://jsonplaceholder.typicode.com/users')

# %%
resultado = json.loads(dados_usuarios.text)

# %%
dados_usuarios_normalizado = pd.json_normalize(resultado, sep='_')

# %%
dados_usuarios_normalizado
# Out:
#    id                      name          username                      email  \
# 0   1             Leanne Graham              Bret          Sincere@april.biz
# 1   2              Ervin Howell         Antonette          Shanna@melissa.tv
# 2   3          Clementine Bauch          Samantha         Nathan@yesenia.net
# 3   4          Patricia Lebsack          Karianne  Julianne.OConner@kory.org
# 4   5          Chelsey Dietrich            Kamren   Lucio_Hettinger@annie.ca
# 5   6      Mrs. Dennis Schulist  Leopoldo_Corkery    Karley_Dach@jasper.info
# 6   7           Kurtis Weissnat      Elwyn.Skiles     Telly.Hoeger@billy.biz
# 7   8  Nicholas Runolfsdottir V     Maxime_Nienow       Sherwood@rosamond.me
# 8   9           Glenna Reichert          Delphine    Chaim_McDermott@dana.io
# 9  10        Clementina DuBuque    Moriah.Stanton     Rey.Padberg@karina.biz
#
#                    phone        website     address_street address_suite  \
# ...

# %%
url_html = "https://pt.wikipedia.org/wiki/Lista_de_pa%C3%ADses_por_popula%C3%A7%C3%A3o"

# %%
tabelas_html = pd.read_html('/content/Lista de países por população – Wikipédia, a enciclopédia livre.html')

# %%
len(tabelas_html)
# Out:
# 3

# %%
df = tabelas_html[0]
df.head()
# Out:
#    Unnamed: 0 Posição País (ou território dependente) Estimativa da ONU  \
# 0         NaN       1                           Índia     1 417 492 000
# 1         NaN       2                   China[nota 1]     1 407 934 000
# 2         NaN       3                  Estados Unidos       342 181 000
# 3         NaN       4                       Indonésia       285 783 000
# 4         NaN       5                       Paquistão       256 204 000
#
#   Crescimento desde a última estimativa  Estimativa Oficial
# 0                           -12 692 000  Estimativa oficial
# 1                            -1 390 000       Censo oficial
# 2                            -2 084 000       Censo oficial
# 3                            +3 337 000  Estimativa oficial
# 4                            +6 567 000  Estimativa oficial

# %% [markdown]
# ## Criar o banco de dados local com a biblioteca SQLAlchemy.

# %%
import sqlalchemy

# %%
from sqlalchemy import create_engine, MetaData, Table, inspect

# %%
engine = create_engine('sqlite:///:memory:')

# %%
utl_csv_bd = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/clientes_banco.csv'

# %%
dados_csv_bd = pd.read_csv(utl_csv_bd)

# %%
dados_csv_bd.head()
# Out:
#    ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0     5008804     32   Ensino superior  União-estável                2
# 1     5008805     32   Ensino superior  União-estável                2
# 2     5008806     58      Ensino médio         Casado                2
# 3     5008808     52      Ensino médio       Solteiro                1
# 4     5008809     52      Ensino médio       Solteiro                1
#
#     Categoria_de_renda   Ocupacao  Anos_empregado  Rendimento_anual  \
# 0            Empregado      Outro              12          427500.0
# 1            Empregado      Outro              12          427500.0
# 2            Empregado  Segurança               3          112500.0
# 3  Associado comercial     Vendas               8          270000.0
# 4  Associado comercial     Vendas               8          270000.0
#
#    Tem_carro                   Moradia
# 0          1       Apartamento alugado
# 1          1       Apartamento alugado
# ...

# %% [markdown]
# ## Escrever os dados do arquivo CSV neste banco de dados local.

# %%
dados_csv_bd.to_sql('clientes', engine, index=False)
# Out:
# 438463

# %%
inspector = inspect(engine)

# %%
print(inspector.get_table_names())
# Out:
# ['clientes']

# %%
query = 'SELECT * FROM clientes WHERE ID_Cliente <= "6840104"'

# %% [markdown]
# ## Consulta de teste

# %%
ids = pd.read_sql(query, engine)

# %%
ids
# Out:
#        ID_Cliente  Idade Grau_escolaridade Estado_civil  Tamanho_familia  \
# 0         6840272     36   Ensino superior   Divorciado                1
# 1         6840273     36   Ensino superior   Divorciado                1
# 2         6840274     36   Ensino superior   Divorciado                1
# 3         6840284     32   Ensino superior       Casado                2
# 4         6840287     32   Ensino superior       Casado                2
# ...           ...    ...               ...          ...              ...
# 13766     6840104     62      Ensino médio   Divorciado                1
# 13767     6840222     43      Ensino médio     Solteiro                1
# 13768     6841878     22   Ensino superior     Solteiro                1
# 13769     6842765     59      Ensino médio       Casado                2
# 13770     6842885     51      Ensino médio       Casado                2
#
#         Categoria_de_renda          Ocupacao  Anos_empregado  \
# ...

# %% [markdown]
# ## Atualizar o registro do cliente de ID 6840104 que teve o rendimento anual alterado para 300000.

# %%
from sqlalchemy import text

query = text('UPDATE clientes SET Rendimento_anual = "300000" WHERE ID_CLIENTE = 6840104')

with engine.connect() as conn:
    conn.execute(query)
    conn.commit()

# %%
pd.read_sql_table('clientes', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008809     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438458     6840104     62      Ensino médio     Divorciado                1
# 438459     6840222     43      Ensino médio       Solteiro                1
# 438460     6841878     22   Ensino superior       Solteiro                1
# 438461     6842765     59      Ensino médio         Casado                2
# 438462     6842885     51      Ensino médio         Casado                2
#
# ...

# %% [markdown]
# ## Excluir o registro do cliente de ID 5008809, pois essa pessoa não possui mais conta na instituição financeira.

# %% [markdown]
# ## Consultando o cliente que será excluído

# %%
pd.read_sql_table('clientes', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008809     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438458     6840104     62      Ensino médio     Divorciado                1
# 438459     6840222     43      Ensino médio       Solteiro                1
# 438460     6841878     22   Ensino superior       Solteiro                1
# 438461     6842765     59      Ensino médio         Casado                2
# 438462     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
from sqlalchemy import text

query = text("DELETE FROM clientes WHERE ID_Cliente = 5008809")

with engine.connect() as conn:
    conn.execute(query)
    conn.commit()

# %% [markdown]
# ## Check se foi excluido

# %%
pd.read_sql_table('clientes', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008810     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438457     6840104     62      Ensino médio     Divorciado                1
# 438458     6840222     43      Ensino médio       Solteiro                1
# 438459     6841878     22   Ensino superior       Solteiro                1
# 438460     6842765     59      Ensino médio         Casado                2
# 438461     6842885     51      Ensino médio         Casado                2
#
# ...

# %% [markdown]
# ## Criar um novo registro de cliente

# %%
from sqlalchemy import text

query = text("""
INSERT INTO clientes (
    ID_Cliente,
    Idade,
    Grau_escolaridade,
    Estado_civil,
    Tamanho_familia,
    Categoria_de_renda,
    Ocupacao,
    Anos_empregado,
    Rendimento_anual,
    Tem_carro,
    Moradia
)
VALUES (
    6850985,
    33,
    'Doutorado',
    'Solteiro',
    1,
    'Empregado',
    'TI',
    2,
    290000,
    0,
    'Casa/apartamento próprio'
)
""")

with engine.connect() as conn:
    conn.execute(query)
    conn.commit()

# %%
pd.read_sql_table('clientes', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008810     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438459     6841878     22   Ensino superior       Solteiro                1
# 438460     6842765     59      Ensino médio         Casado                2
# 438461     6842885     51      Ensino médio         Casado                2
# 438462     6850985     33         Doutorado       Solteiro                1
# 438463     6850985     33         Doutorado       Solteiro                1
#
# ...
