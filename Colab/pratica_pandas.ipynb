# %% [markdown]
# <a href="https://colab.research.google.com/github/Samuel442/Python/blob/main/Colab/pratica_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) Importe o arquivo alunos.csv e armazene seu conteúdo em um DataFrame Pandas.

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv')

# %% [markdown]
# 2) Visualize as primeiras 7 linhas do DataFrame e as 5 últimas.

# %%
print(df.head(7))
print(df.tail(5))
# Out:
#     Nome  Idade  Notas  Aprovado
# 0    Ary     20    7.5      True
# 1    Ana     18    NaN     False
# 2  Cátia     27    2.5     False
# 3  Denis     18    5.0     False
# 4   Beto     21   10.0      True
# 5  Bruna     23    NaN     False
# 6   Dara     21    7.0      True
#       Nome  Idade  Notas  Aprovado
# 13   Mirla     25    9.0      True
# 14   Paulo     37    NaN     False
# 15  Mylena     29    7.0      True
# 16   Lucas     33    NaN     False
# 17   Nadia     34    8.0      True

# %% [markdown]
# 3) Confira a quantidade de linhas e colunas desse DataFrame.

# %%
print(df.shape)
# Out:
# (18, 4)

# %% [markdown]
# 4) Explore as colunas do DataFrame e analise os tipos dos dados presentes em cada coluna.

# %%
import pandas as pd

print("📌 Nomes das colunas:")
print(df.columns)

print("\n📌 Tipos de dados:")
print(df.dtypes)

print("\n📌 Resumo geral:")
print(df.info())

print("\n📌 Primeiras linhas:")
print(df.head())
# Out:
# 📌 Nomes das colunas:
# Index(['Nome', 'Idade', 'Notas', 'Aprovado'], dtype='object')
#
# 📌 Tipos de dados:
# Nome         object
# Idade         int64
# Notas       float64
# Aprovado       bool
# dtype: object
#
# 📌 Resumo geral:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Nome      18 non-null     object
#  1   Idade     18 non-null     int64
#  2   Notas     12 non-null     float64
#  3   Aprovado  18 non-null     bool
# dtypes: bool(1), float64(1), int64(1), object(1)
# memory usage: 582.0+ bytes
# None
#
# 📌 Primeiras linhas:
#     Nome  Idade  Notas  Aprovado
# 0    Ary     20    7.5      True
# 1    Ana     18    NaN     False
# 2  Cátia     27    2.5     False
# 3  Denis     18    5.0     False
# 4   Beto     21   10.0      True

# %% [markdown]
# O time de ML chegou com algumas demandas de última hora para resolvermos nesse momento da análise exploratória. Essas demandas são:

# %% [markdown]
# 1) Calcular a média de quartos dos imóveis;

# %%
url = "https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv"

# %%
df = pd.read_csv(url, sep=';')
df.head()
df.columns
df.dtypes
media_quartos = df['Quartos'].mean()
media_quartos
# Out:
# np.float64(1.7713895631067962)

# %% [markdown]
# 2) Conferir quantos bairros únicos existem na nossa base de dados;

# %%
num_bairros = df['Bairro'].unique()
num_bairros
# Out:
# array(['Copacabana', 'Jardim Botânico', 'Barra da Tijuca', 'Centro',
#        'Higienópolis', 'Vista Alegre', 'Cachambi', 'Ramos', 'Grajaú',
#        'Lins de Vasconcelos', 'Botafogo', 'Taquara',
#        'Freguesia (Jacarepaguá)', 'Tijuca', 'Olaria', 'Leblon',
#        'São Cristóvão', 'Ipanema', 'Campo Grande',
#        'Recreio dos Bandeirantes', 'Jardim Oceânico', 'Humaitá',
#        'Península', 'Méier', 'Vargem Pequena', 'Maracanã', 'Jacarepaguá',
#        'Vargem Grande', 'São Conrado', 'Maria da Graça', 'Vila Valqueire',
#        'Gávea', 'Cosme Velho', 'Bonsucesso', 'Todos os Santos',
#        'Laranjeiras', 'Itanhangá', 'Flamengo', 'Praça Seca', 'Piedade',
#        'Lagoa', 'Santo Cristo', 'Largo do Machado', 'Catete',
#        'Jardim Carioca', 'Benfica', 'Glória', 'Vila Isabel',
#        'Quintino Bocaiúva', 'São Francisco Xavier', 'Rocha Miranda',
#        'Engenho Novo', 'Engenho de Dentro', 'Cidade Nova', 'Pilares',
#        'Arpoador', 'Tomás Coelho', 'Água Santa', 'Ilha do Governador',
#        'Jardim Sulacap', 'Del Castilho', 'Oswaldo Cruz', 'Vila da Penha',
#        'Anil', 'Tanque', 'Vaz Lobo', 'Madureira', 'Pechincha', 'Leme',
#        'Irajá', 'Andaraí', 'Cordovil', 'Urca', 'Penha', 'Vigário Geral',
#        'Gardênia Azul', 'Santa Cruz', 'Rio Comprido', 'Santa Teresa',
#        'Inhaúma', 'Marechal Hermes', 'Pavuna', 'Curicica', 'Santíssimo',
#        'Moneró', 'Jardim Guanabara', 'Vila Militar', 'Camorim',
#        'Cascadura', 'Manguinhos', 'Praia da Bandeira', 'Saúde', 'Joá',
#        'Gamboa', 'Bangu', 'Colégio', 'Guadalupe', 'Realengo', 'Fátima',
#        'Inhoaíba', 'Rocha', 'Jabour', 'Parada de Lucas', 'Braz de Pina',
#        'Vila Kosmos', 'Vicente de Carvalho', 'Praça da Bandeira',
#        'Encantado', 'Campinho', 'Penha Circular',
#        'Ricardo de Albuquerque', 'Guaratiba', 'Lapa', 'Riachuelo',
#        'Portuguesa', 'Catumbi', 'Castelo', 'Parque Anchieta', 'Abolição',
#        'Caju', 'Alto da Boa Vista', 'Bento Ribeiro', 'Estácio',
#        'Jardim América', 'Paciência', 'Pedra de Guaratiba',
#        'Padre Miguel', 'Zumbi', 'Sampaio', 'Anchieta', 'Tauá', 'Icaraí',
#        'Cinelândia', 'Senador Vasconcelos', 'Barra de Guaratiba',
#        'Paquetá', 'Senador Camará', 'Turiaçu',
#        'Freguesia (Ilha do Governador)', 'Honório Gurgel', 'Cosmos',
#        'Pitangueiras', 'Vidigal', 'Usina', 'Cacuia', 'Ribeira', 'Jacaré',
#        'Cocotá', 'Engenho da Rainha', 'Cachamorra', 'Itaguaí',
#        'Cavalcanti', 'Cidade de Deus', 'Magalhães Bastos', 'Coelho Neto',
#        'Vasco da Gama', 'Bancários', 'Rio da Prata', 'Cidade Jardim',
#        'Parque Colúmbia', 'Grumari', 'Sepetiba'], dtype=object)

# %% [markdown]
# 3) Analisar quais bairros possuem a média de valor de aluguel mais elevadas;

# %%
df.head
df
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# 0        40  1700.0       500.0    60.0
# 1       100  7000.0         NaN     NaN
# 2       150  5200.0      4020.0  1111.0
# 3        15   800.0       390.0    20.0
# 4        48   800.0       230.0     NaN
# ...     ...     ...         ...     ...
# 32955    27   800.0       350.0    25.0
# 32956    78  1800.0       800.0    40.0
# 32957    48  1400.0       509.0    37.0
# 32958    70  3000.0       760.0     NaN
# 32959   250  6500.0      4206.0  1109.0
#
# [32960 rows x 9 columns]

# %%
media_por_bairro = (
    df.groupby('Bairro')['Valor']
    .mean()
    .sort_values(ascending=False)
)
media_por_bairro
# Out:
# Bairro
# Jacarepaguá         314143.489637
# Irajá               154610.470588
# Caju                120264.782609
# Vasco da Gama       120000.000000
# Cidade Nova          88166.692308
#                         ...
# Inhoaíba               738.888889
# Turiaçu                733.333333
# Magalhães Bastos       726.666667
# Santíssimo             709.090909
# Senador Camará         635.000000
# Name: Valor, Length: 162, dtype: float64

# %% [markdown]
# 4) Criar um gráfico de barras horizontais que apresente os 5 bairros com as médias de valores de aluguel mais elevadas.

# %%
import matplotlib.pyplot as plt

# Agrupar e calcular média por bairro
media_por_bairro = df.groupby("Bairro")["Valor"].mean()

# Pegar os 5 bairros com maior média
top5 = media_por_bairro.sort_values(ascending=False).head(5)

# Plotar gráfico de barras horizontais
plt.figure(figsize=(10, 6))
top5.plot(kind='barh', color='skyblue')  # barh = barras horizontais

plt.xlabel("Valor médio do aluguel")
plt.ylabel("Bairro")
plt.title("Top 5 bairros com as maiores médias de aluguel")
plt.gca().invert_yaxis()  # inverte a ordem para que o maior fique no topo

plt.tight_layout()
plt.show()

# %% [markdown]
# Durante o desenvolvimento do nosso projeto, nós aplicamos alguns filtros na nossa base de dados e salvamos os DataFrames resultantes em diferentes variáveis, sendo elas: df_1 e df_2.
#
# Com base nisso, salve esses DataFrames em 2 arquivos csv distintos para que o time de ML possa ter acesso a esses dados de forma mais prática.

# %%
url = "https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv"

df_1 = pd.read_csv(url, sep=';')
df_2 = pd.read_csv(url, sep=';')

df_1.to_csv('df_1.csv', index=False)
df_2.to_csv('df_2.csv', index=False)

# %%
df_1.to_json('df_1.json')
df_2.to_json('df_2.json')

# %% [markdown]
# 1) Verifique se a base de dados possui dados nulos e, caso tenha, realize o tratamento desses dados nulos da forma que achar mais coerente com a situação.

# %%
url_2 = "https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv"

verifica_nulo = pd.read_csv(url_2)
verifica_nulo.isnull().sum()

df_alunos = pd.read_csv(url_2)
df_alunos.fillna(0, inplace=True)
df_alunos.isnull().sum()
# Out:
# Nome        0
# Idade       0
# Notas       0
# Aprovado    0
# dtype: int64

# %% [markdown]
# 2) Os alunos "Alice" e "Carlos", não fazem mais parte da turma. Sendo assim, remova-os da base de dados.

# %%
Carlos = "Carlos"
Alice = "Alice"

df_alunos = df_alunos[df_alunos['Nome'] != Carlos]
df_alunos = df_alunos[df_alunos['Nome'] != Alice]
df_alunos
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# 3) Aplique um filtro que selecione apenas os alunos que foram aprovados.

# %%
df_aprovados = df_alunos[df_alunos['Aprovado'] == True]
df_aprovados
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    7.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    7.0      True
# 17      Nadia     34    8.0      True

# %% [markdown]
# 4) Salve o DataFrame que possui apenas os alunos aprovados em um arquivo csv chamado "alunos_aprovados.csv".

# %%
# Definir o nome do novo arquivo
nome_arquivo_aprovados = 'alunos_aprovados.csv'

df_aprovados.to_csv(nome_arquivo_aprovados, index=False)

# %% [markdown]
# Extra: Ao conferir as notas dos alunos aprovados, notamos que algumas notas estavam incorretas. As alunas que tiraram nota 7.0, na verdade, tinham um ponto extra que não foi contabilizado. Sendo assim, substitua as notas 7.0 da base de dados por 8.0. Dica: pesquise pelo método replace.

# %%
df_alunos['Notas']  = df_alunos['Notas'].replace(7.0, 8.0)
df_alunos
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    8.0      True
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    8.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# 1) Os alunos participaram de uma atividade extracurricular e ganharam pontos extras. Esses pontos extras correspondem a 40% da nota atual de cada um deles. Com base nisso, crie uma coluna chamada "Pontos_extras" que contenha os pontos extras de cada aluno, ou seja, 40% da nota atual deles.

# %%
df_alunos['Pontos_extras'] = df_alunos['Notas'] * 0.4
df_alunos
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras
# 0         Ary     20    7.5      True            3.0
# 1         Ana     18    0.0     False            0.0
# 2       Cátia     27    2.5     False            1.0
# 3       Denis     18    5.0     False            2.0
# 4        Beto     21   10.0      True            4.0
# 5       Bruna     23    0.0     False            0.0
# 6        Dara     21    8.0      True            3.2
# 9       Vitor     28    0.0     False            0.0
# 10     Daniel     21    0.0     False            0.0
# 11       Igor     24    4.5     False            1.8
# 12  Sthefanie     26    9.5      True            3.8
# 13      Mirla     25    9.0      True            3.6
# 14      Paulo     37    0.0     False            0.0
# 15     Mylena     29    8.0      True            3.2
# 16      Lucas     33    0.0     False            0.0
# 17      Nadia     34    8.0      True            3.2

# %% [markdown]
# 2) Crie mais uma coluna, chamada "Notas_finais" que possua as notas de cada aluno somada com os pontos extras.

# %%
df_alunos['Notas_finais'] = df_alunos['Notas'] + df_alunos['Pontos_extras']
df_alunos
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais
# 0         Ary     20    7.5      True            3.0          10.5
# 1         Ana     18    0.0     False            0.0           0.0
# 2       Cátia     27    2.5     False            1.0           3.5
# 3       Denis     18    5.0     False            2.0           7.0
# 4        Beto     21   10.0      True            4.0          14.0
# 5       Bruna     23    0.0     False            0.0           0.0
# 6        Dara     21    8.0      True            3.2          11.2
# 9       Vitor     28    0.0     False            0.0           0.0
# 10     Daniel     21    0.0     False            0.0           0.0
# 11       Igor     24    4.5     False            1.8           6.3
# 12  Sthefanie     26    9.5      True            3.8          13.3
# 13      Mirla     25    9.0      True            3.6          12.6
# 14      Paulo     37    0.0     False            0.0           0.0
# 15     Mylena     29    8.0      True            3.2          11.2
# 16      Lucas     33    0.0     False            0.0           0.0
# 17      Nadia     34    8.0      True            3.2          11.2

# %% [markdown]
# 3) Como houve uma pontuação extra, alguns alunos que não tinham sido aprovados antes podem ter sido aprovados agora. Com base nisso, crie uma coluna chamada "Aprovado_final" com os seguintes valores:
#
# True: caso o aluno esteja aprovado (nota final deve ser maior ou igual a 6);
# False: caso o aluno esteja reprovado (nota final deve ser menor que 6).

# %%
df_alunos['Aprovado_final'] = df_alunos['Notas_finais'] >= 6
df_alunos
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais  \
# 0         Ary     20    7.5      True            3.0          10.5
# 1         Ana     18    0.0     False            0.0           0.0
# 2       Cátia     27    2.5     False            1.0           3.5
# 3       Denis     18    5.0     False            2.0           7.0
# 4        Beto     21   10.0      True            4.0          14.0
# 5       Bruna     23    0.0     False            0.0           0.0
# 6        Dara     21    8.0      True            3.2          11.2
# 9       Vitor     28    0.0     False            0.0           0.0
# 10     Daniel     21    0.0     False            0.0           0.0
# 11       Igor     24    4.5     False            1.8           6.3
# 12  Sthefanie     26    9.5      True            3.8          13.3
# 13      Mirla     25    9.0      True            3.6          12.6
# 14      Paulo     37    0.0     False            0.0           0.0
# 15     Mylena     29    8.0      True            3.2          11.2
# 16      Lucas     33    0.0     False            0.0           0.0
# 17      Nadia     34    8.0      True            3.2          11.2
#
#     Aprovado_final
# 0             True
# 1            False
# 2            False
# 3             True
# 4             True
# 5            False
# 6             True
# 9            False
# 10           False
# 11            True
# 12            True
# 13            True
# 14           False
# 15            True
# 16           False
# 17            True

# %% [markdown]
# 4) Faça uma seleção e verifique quais alunos não tinham sido aprovados anteriormente, mas foram aprovados após a soma dos pontos extras.

# %%
df_alunos['Situacao_depois_d_extra'] = df_alunos.apply(
    lambda row:
        'passou depois do extra' if (row['Aprovado'] == False and row['Aprovado_final'] == True)
        else 'passou direto' if (row['Aprovado'] == True and row['Aprovado_final'] == True)
        else 'reprovou',
    axis=1
)
df_alunos
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais  \
# 0         Ary     20    7.5      True            3.0          10.5
# 1         Ana     18    0.0     False            0.0           0.0
# 2       Cátia     27    2.5     False            1.0           3.5
# 3       Denis     18    5.0     False            2.0           7.0
# 4        Beto     21   10.0      True            4.0          14.0
# 5       Bruna     23    0.0     False            0.0           0.0
# 6        Dara     21    8.0      True            3.2          11.2
# 9       Vitor     28    0.0     False            0.0           0.0
# 10     Daniel     21    0.0     False            0.0           0.0
# 11       Igor     24    4.5     False            1.8           6.3
# 12  Sthefanie     26    9.5      True            3.8          13.3
# 13      Mirla     25    9.0      True            3.6          12.6
# 14      Paulo     37    0.0     False            0.0           0.0
# 15     Mylena     29    8.0      True            3.2          11.2
# 16      Lucas     33    0.0     False            0.0           0.0
# 17      Nadia     34    8.0      True            3.2          11.2
#
#     Aprovado_final Situacao_depois_d_extra
# 0             True           passou direto
# 1            False                reprovou
# 2            False                reprovou
# 3             True  passou depois do extra
# 4             True           passou direto
# 5            False                reprovou
# 6             True           passou direto
# 9            False                reprovou
# 10           False                reprovou
# 11            True  passou depois do extra
# 12            True           passou direto
# 13            True           passou direto
# 14           False                reprovou
# 15            True           passou direto
# 16           False                reprovou
# 17            True           passou direto
