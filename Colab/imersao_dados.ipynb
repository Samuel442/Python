# %% [markdown]
# <a href="https://colab.research.google.com/github/Samuel442/Python/blob/main/Colab/imersao_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/guilhermeonrails/data-jobs/refs/heads/main/salaries.csv')

# %%
df.head(10)
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
# 5     2025.0               EN              FT       Data Engineer   80000
# 6     2025.0               SE              FT      Data Scientist  185000
# 7     2025.0               SE              FT      Data Scientist  148000
# 8     2025.0               MI              FT      Data Scientist  135000
# 9     2025.0               MI              FT      Data Scientist  108000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133349 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   work_year           133339 non-null  float64
#  1   experience_level    133349 non-null  object
#  2   employment_type     133349 non-null  object
#  3   job_title           133349 non-null  object
#  4   salary              133349 non-null  int64
#  5   salary_currency     133349 non-null  object
#  6   salary_in_usd       133349 non-null  int64
#  7   employee_residence  133349 non-null  object
#  8   remote_ratio        133349 non-null  int64
#  9   company_location    133349 non-null  object
#  10  company_size        133349 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
df.shape
# Out:
# (133349, 11)

# %%
linhas, colunas = df.shape[0], df.shape[1]

# %%
print('linhas: ', linhas)
print('colunas: ',colunas)
# Out:
# linhas:  133349
# colunas:  11

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df['senioridade'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'senioridade'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4223083479.py in <cell line: 0>()
# ----> 1 df['senioridade'].value_counts()
#
# ...

# %%
df['contrato'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'contrato'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1698431540.py in <cell line: 0>()
# ----> 1 df['contrato'].value_counts()
#
# ...

# %%
df['remoto'].value_counts()
# Out:
# remoto
# 0      105312
# 100     27718
# 50        319
# Name: count, dtype: int64

# %%
df['tamanho_empresa'].value_counts()
# Out:
# tamanho_empresa
# M    129561
# L      3574
# S       214
# Name: count, dtype: int64

# %%
# Out:
# contrato
# Tempo Integral    132563
# Contrato             394
# Meio Período         376
# Freelancer            16
# Name: count, dtype: int64

# %%
# Out:
# tamanho_empresa
# Média      129561
# Grande       3574
# Pequena       214
# Name: count, dtype: int64

# %%
remoto = {
    0: 'Presencial',
    50: 'Híbrido',
    100: 'Remoto'
}

df['remoto'] = df['remoto'].replace(remoto)
df['remoto'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'remoto'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1139403035.py in <cell line: 0>()
#       5 }
#       6
# ----> 7 df['remoto'] = df['remoto'].replace(remoto)
# ...

# %%
df.head()
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# 1             USD         136000                 US           100
# 2             USD         158800                 AU             0
# 3             USD         139200                 AU             0
# 4             USD          90000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# ...

# %%
df.describe(include = 'object')
# Out:
#        experience_level employment_type       job_title salary_currency  \
# count            133349          133349          133349          133349
# unique                4               4             390              26
# top                  SE              FT  Data Scientist             USD
# freq              77241          132563           17314          126140
#
#        employee_residence company_location company_size
# count              133349           133349       133349
# unique                102               95            3
# top                    US               US            M
# freq               119579           119641       129561

# %%
df.describe()
# Out:
#            work_year        salary  salary_in_usd   remote_ratio
# count  133339.000000  1.333490e+05  133349.000000  133349.000000
# mean     2024.358770  1.632833e+05  157617.272098      20.905669
# std         0.680627  2.173860e+05   74288.363097      40.590044
# min      2020.000000  1.400000e+04   15000.000000       0.000000
# 25%      2024.000000  1.060200e+05  106000.000000       0.000000
# 50%      2024.000000  1.470000e+05  146206.000000       0.000000
# 75%      2025.000000  1.990000e+05  198000.000000       0.000000
# max      2025.000000  3.040000e+07  800000.000000     100.000000

# %%
######## Aula 2

# %%
df.isnull()
# Out:
#         work_year  experience_level  employment_type  job_title  salary  \
# 0           False             False            False      False   False
# 1           False             False            False      False   False
# 2           False             False            False      False   False
# 3           False             False            False      False   False
# 4           False             False            False      False   False
# ...           ...               ...              ...        ...     ...
# 133344      False             False            False      False   False
# 133345      False             False            False      False   False
# 133346      False             False            False      False   False
# 133347      False             False            False      False   False
# 133348      False             False            False      False   False
#
#         salary_currency  salary_in_usd  employee_residence  remote_ratio  \
# ...

# %%
df.head()
# Out:
#    work_year experience_level employment_type           job_title  salary  \
# 0     2025.0               SE              FT  Solutions Engineer  214000
# 1     2025.0               SE              FT  Solutions Engineer  136000
# 2     2025.0               MI              FT       Data Engineer  158800
# 3     2025.0               MI              FT       Data Engineer  139200
# 4     2025.0               EN              FT       Data Engineer   90000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         214000                 US           100
# 1             USD         136000                 US           100
# 2             USD         158800                 AU             0
# 3             USD         139200                 AU             0
# 4             USD          90000                 US             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# ...

# %%
df.rename(columns={
    'work_year': 'ano',
    'experience_level': 'senioridade',
    'employment_type': 'contrato',
    'job_title': 'cargo',
    'salary': 'salario',
    'salary_currency': 'moeda',
    'salary_in_usd': 'usd',
    'employee_residence': 'residencia',
    'remote_ratio': 'remoto',
    'company_location': 'empresa',
    'company_size': 'tamanho_empresa'
}, inplace=True)

# %%
df.columns
# Out:
# Index(['ano', 'senioridade', 'contrato', 'cargo', 'salario', 'moeda', 'usd',
#        'residencia', 'remoto', 'empresa', 'tamanho_empresa'],
#       dtype='object')

# %%
df.head()
# Out:
#       ano senioridade contrato               cargo  salario moeda     usd  \
# 0  2025.0          SE       FT  Solutions Engineer   214000   USD  214000
# 1  2025.0          SE       FT  Solutions Engineer   136000   USD  136000
# 2  2025.0          MI       FT       Data Engineer   158800   USD  158800
# 3  2025.0          MI       FT       Data Engineer   139200   USD  139200
# 4  2025.0          EN       FT       Data Engineer    90000   USD   90000
#
#   residencia  remoto empresa tamanho_empresa
# 0         US     100      US               M
# 1         US     100      US               M
# 2         AU       0      AU               M
# 3         AU       0      AU               M
# 4         US       0      US               M

# %%
df.isnull().sum()
# Out:
# ano                10
# senioridade         0
# contrato            0
# cargo               0
# salario             0
# moeda               0
# usd                 0
# residencia          0
# remoto              0
# empresa             0
# tamanho_empresa     0
# dtype: int64

# %%
df['ano'].unique()
# Out:
# array([2025.,   nan, 2024., 2022., 2023., 2020., 2021.])

# %%
df[df.isnull().any(axis=1)]
# Out:
#         ano senioridade contrato                      cargo  salario moeda  \
# 5588    NaN          SE       FT            Product Manager   184500   USD
# 59692   NaN          MI       FT                   Engineer   110000   USD
# 59710   NaN          EN       FT             Data Scientist   208800   USD
# 59759   NaN          SE       FT          Software Engineer   135000   USD
# 59789   NaN          SE       FT                   Engineer   112000   USD
# 131000  NaN          SE       FT  Machine Learning Engineer   163800   USD
# 131006  NaN          SE       FT     Data Analytics Manager   204500   USD
# 133054  NaN          EN       FT             Data Scientist    40000   USD
# 133281  NaN          MI       FT  Machine Learning Engineer   180000   PLN
# 133317  NaN          MI       FT             Data Scientist   130000   USD
#
#            usd residencia  remoto empresa tamanho_empresa
# 5588    184500         US       0      US               M
# ...

# %%
import numpy as np
# criação de um dataframe de teste para completar salários
df_salarios = pd.DataFrame({
    'nome': ['Ana', 'Bruno', 'Carlos', 'Daniele', 'Val'],
    'salario': [4000, np.nan, 5000, np.nan, 100000]
})

df_salarios['salario_media'] = df_salarios['salario'].fillna(df_salarios['salario'].mean().round(2))
df_salarios['salario_mediana'] = df_salarios['salario'].fillna(df_salarios['salario'].median())
df_salarios
# Out:
#       nome   salario  salario_media  salario_mediana
# 0      Ana    4000.0        4000.00           4000.0
# 1    Bruno       NaN       36333.33           5000.0
# 2   Carlos    5000.0        5000.00           5000.0
# 3  Daniele       NaN       36333.33           5000.0
# 4      Val  100000.0      100000.00         100000.0

# %%
df_temperaturas = pd.DataFrame({
    'dia': ['segunda', 'terça', 'quarta', 'quinta', 'sexta'],
    'temperatura': [30, np.nan, np.nan, 28, 27]

})

df_temperaturas['preenchido_ffill'] = df_temperaturas['temperatura'].ffill()
df_temperaturas
# Out:
#        dia  temperatura  preenchido_ffill
# 0  segunda         30.0              30.0
# 1    terça          NaN              30.0
# 2   quarta          NaN              30.0
# 3   quinta         28.0              28.0
# 4    sexta         27.0              27.0

# %%
df_temperaturas = pd.DataFrame({
    'dia': ['segunda', 'terça', 'quarta', 'quinta', 'sexta'],
    'temperatura': [30, np.nan, np.nan, 28, 27]

})

df_temperaturas['preenchido_bfill'] = df_temperaturas['temperatura'].bfill()
df_temperaturas
# Out:
#        dia  temperatura  preenchido_bfill
# 0  segunda         30.0              30.0
# 1    terça          NaN              28.0
# 2   quarta          NaN              28.0
# 3   quinta         28.0              28.0
# 4    sexta         27.0              27.0

# %%
df_cidades = pd.DataFrame({
    'nome': ['Ana', 'Bruno', 'Carlos', 'Daniele', 'Val'],
    'cidade': ['São Paulo', np.nan, 'Curitiba', np.nan, 'Belém']
})

df_cidades['cidade_preenchida'] = df_cidades['cidade'].fillna('Não informado')
df_cidades
# Out:
#       nome     cidade cidade_preenchida
# 0      Ana  São Paulo         São Paulo
# 1    Bruno        NaN     Não informado
# 2   Carlos   Curitiba          Curitiba
# 3  Daniele        NaN     Não informado
# 4      Val      Belém             Belém

# %%
df_limpo = df.dropna()

# %%
df_limpo.isnull().sum()
# Out:
# ano                0
# senioridade        0
# contrato           0
# cargo              0
# salario            0
# moeda              0
# usd                0
# residencia         0
# remoto             0
# empresa            0
# tamanho_empresa    0
# dtype: int64

# %%
df_limpo.head()
# Out:
#       ano senioridade contrato               cargo  salario moeda     usd  \
# 0  2025.0          SE       FT  Solutions Engineer   214000   USD  214000
# 1  2025.0          SE       FT  Solutions Engineer   136000   USD  136000
# 2  2025.0          MI       FT       Data Engineer   158800   USD  158800
# 3  2025.0          MI       FT       Data Engineer   139200   USD  139200
# 4  2025.0          EN       FT       Data Engineer    90000   USD   90000
#
#   residencia  remoto empresa tamanho_empresa
# 0         US     100      US               M
# 1         US     100      US               M
# 2         AU       0      AU               M
# 3         AU       0      AU               M
# 4         US       0      US               M

# %%
df_limpo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133339 entries, 0 to 133348
# Data columns (total 11 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   ano              133339 non-null  float64
#  1   senioridade      133339 non-null  object
#  2   contrato         133339 non-null  object
#  3   cargo            133339 non-null  object
#  4   salario          133339 non-null  int64
#  5   moeda            133339 non-null  object
#  6   usd              133339 non-null  int64
#  7   residencia       133339 non-null  object
#  8   remoto           133339 non-null  int64
#  9   empresa          133339 non-null  object
#  10  tamanho_empresa  133339 non-null  object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 12.2+ MB

# %%
df_limpo = df_limpo.assign(ano = df_limpo['ano'].astype('int64'))
df_limpo
# Out:
#          ano senioridade contrato                     cargo  salario moeda  \
# 0       2025          SE       FT        Solutions Engineer   214000   USD
# 1       2025          SE       FT        Solutions Engineer   136000   USD
# 2       2025          MI       FT             Data Engineer   158800   USD
# 3       2025          MI       FT             Data Engineer   139200   USD
# 4       2025          EN       FT             Data Engineer    90000   USD
# ...      ...         ...      ...                       ...      ...   ...
# 133344  2020          SE       FT            Data Scientist   412000   USD
# 133345  2021          MI       FT  Principal Data Scientist   151000   USD
# 133346  2020          EN       FT            Data Scientist   105000   USD
# 133347  2020          EN       CT     Business Data Analyst   100000   USD
# 133348  2021          SE       FT            Data Scientist  7000000   INR
#
#            usd residencia  remoto empresa tamanho_empresa
# ...

# %%
df_limpo.head()
# Out:
#     ano senioridade contrato               cargo  salario moeda     usd  \
# 0  2025          SE       FT  Solutions Engineer   214000   USD  214000
# 1  2025          SE       FT  Solutions Engineer   136000   USD  136000
# 2  2025          MI       FT       Data Engineer   158800   USD  158800
# 3  2025          MI       FT       Data Engineer   139200   USD  139200
# 4  2025          EN       FT       Data Engineer    90000   USD   90000
#
#   residencia  remoto empresa tamanho_empresa
# 0         US     100      US               M
# 1         US     100      US               M
# 2         AU       0      AU               M
# 3         AU       0      AU               M
# 4         US       0      US               M

# %%
df_limpo['senioridade'].value_counts().plot(kind='bar', title = 'Distribuição de Senioridade')
# Out:
# <Axes: title={'center': 'Distribuição de Senioridade'}, xlabel='senioridade'>

# %%
import seaborn as sns

# %%
sns.barplot(x='senioridade', y='usd', data=df_limpo)
# Out:
# <Axes: xlabel='senioridade', ylabel='usd'>

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='senioridade', y='usd', data=df_limpo)
plt.title('Distribuição de Salário Senioridade')
plt.xlabel('Senioridade')
plt.ylabel('USD')
plt.show()

# %%
df_limpo.groupby('senioridade')['usd'].mean().sort_values(ascending=False)
# Out:
# senioridade
# EX    202027.667813
# SE    172850.838301
# MI    143044.845979
# EN     99034.963267
# Name: usd, dtype: float64

# %%
ordem = df_limpo.groupby('senioridade')['usd'].mean().sort_values(ascending=False).index
ordem
# Out:
# Index(['EX', 'SE', 'MI', 'EN'], dtype='object', name='senioridade')

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='senioridade', y='usd', data=df_limpo, order=ordem)
plt.title('Distribuição de Salário Senioridade')
plt.xlabel('Senioridade')
plt.ylabel('USD')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.histplot(df_limpo['usd'], bins = 70, kde=True)
plt.title('Distribuição de Salário')
plt.xlabel('USD')
plt.ylabel('Frequência')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x = df_limpo['usd'])
plt.title('BoxPlot de Salário')
plt.xlabel('USD')
# Out:
# Text(0.5, 0, 'USD')

# %%
ordem_senioridade = ['SE' 'MI' 'EN' 'EX']
plt.figure(figsize=(8,6))
sns.boxplot(x = 'senioridade', y = 'usd', data=df_limpo, order = ordem_senioridade)
plt.title('BoxPlot de Salário por Senioridade')
plt.xlabel('Senioridade')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3380487121.py in <cell line: 0>()
#       1 ordem_senioridade = ['SE' 'MI' 'EN' 'EX']
#       2 plt.figure(figsize=(8,6))
# ----> 3 sns.boxplot(x = 'senioridade', y = 'usd', data=df_limpo, order = ordem_senioridade)
#       4 plt.title('BoxPlot de Salário por Senioridade')
#       5 plt.xlabel('Senioridade')
#
# /usr/local/lib/python3.11/dist-packages/seaborn/categorical.py in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1632     linecolor = p._complement_color(linecolor, color, p._hue_map)
#    1633
# -> 1634     p.plot_boxes(
#    1635         width=width,
#    1636         dodge=dodge,
#
# ...

# %%
print(df_limpo['senioridade'].unique())
# Out:
# ['SE' 'MI' 'EN' 'EX']

# %%
df_limpo['senioridade_legivel'] = df_limpo['senioridade'].replace({
    'EN': 'Júnior',
    'MI': 'Pleno',
    'SE': 'Sênior',
    'EX': 'Executivo'
})

ordem_legivel = ['Júnior', 'Pleno', 'Sênior', 'Executivo']

plt.figure(figsize=(8,6))
sns.boxplot(x='senioridade_legivel', y='usd', data=df_limpo, order=ordem_legivel)
plt.title('BoxPlot de Salário por Senioridade')
plt.xlabel('Senioridade')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(
    x='senioridade_legivel',
    y='usd',
    data=df_limpo,
    order=['Júnior', 'Pleno', 'Sênior', 'Executivo'],
    palette='Set2'  # <- paleta de cores escolhida
)
plt.title('BoxPlot de Salário por Senioridade')
plt.xlabel('Senioridade')
plt.ylabel('Salário (USD)')
plt.show()
# Out:
# /tmp/ipython-input-1672485530.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
import plotly.express as px

# %%
df_agg = df_limpo.groupby('senioridade_legivel')['usd'].mean().reset_index()
ordem_agg = df_agg.sort_values('usd', ascending=False)['senioridade_legivel']
fig = px.bar(df_agg, x='senioridade_legivel', y='usd', title='Média Salarial por Senioridade', category_orders={'senioridade_legivel': ordem_agg})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(
    remoto_contagem,
    names='tipo_trabalho',   # fatias da pizza
    values='quantidade',     # tamanho de cada fatia
    title='Distribuição por Tipo de Trabalho'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
remoto_contagem = df_limpo['remoto'].value_counts().reset_index()
remoto_contagem.columns = ['tipo_trabalho', 'quantidade']

fig = px.pie(
    remoto_contagem,
    names='tipo_trabalho',   # fatias da pizza
    values='quantidade',     # tamanho de cada fatia
    title='Distribuição por Tipo de Trabalho',
    hole=0.6
)
fig.update_traces(textinfo = 'percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_limpo.head(100)
# Out:
#      ano senioridade contrato               cargo  salario moeda     usd  \
# 0   2025          SE       FT  Solutions Engineer   214000   USD  214000
# 1   2025          SE       FT  Solutions Engineer   136000   USD  136000
# 2   2025          MI       FT       Data Engineer   158800   USD  158800
# 3   2025          MI       FT       Data Engineer   139200   USD  139200
# 4   2025          EN       FT       Data Engineer    90000   USD   90000
# ..   ...         ...      ...                 ...      ...   ...     ...
# 95  2025          SE       FT        Data Analyst   120000   USD  120000
# 96  2025          SE       FT        Data Analyst    90000   USD   90000
# 97  2025          SE       FT        Data Analyst   122000   USD  122000
# 98  2025          SE       FT        Data Analyst    78000   USD   78000
# 99  2025          EN       FT        Data Analyst   110000   USD  110000
#
#    residencia  remoto empresa tamanho_empresa senioridade_legivel
# ...

# %%
# Ver quais cargos existem na base
df_limpo['cargo'].unique()
# Out:
# array(['Solutions Engineer', 'Data Engineer', 'Data Scientist',
#        'BI Developer', 'Data Analyst', 'Applied Scientist',
#        'Systems Engineer', 'Director', 'Associate', 'Software Engineer',
#        'Consultant', 'Analyst', 'Product Manager', 'Software Developer',
#        'Engineer', 'Developer', 'Data Specialist', 'Manager',
#        'Research Scientist', 'Software Architect',
#        'Data Management Analyst', 'Data Reporter',
#        'Computational Biologist', 'Product Designer',
#        'Software Development Engineer', 'Architect',
#        'Data Analytics Manager', 'Principal Statistical Programmer',
#        'Cloud Engineer', 'Data Architect', 'Product Owner', 'Executive',
#        'Business Intelligence Engineer', 'Data Governance Lead',
#        'Data Governance Specialist', 'AI Engineer', 'Solutions Architect',
#        'AI Researcher', 'Machine Learning Engineer', 'Bear Robotics',
#        'Data Strategist', 'Research Engineer', 'Researcher',
# ...

# %%
df_cientistas = df_limpo[df_limpo['cargo'] == 'Data Scientist']
df_cientistas.head()
# Out:
#      ano senioridade contrato           cargo  salario moeda     usd  \
# 6   2025          SE       FT  Data Scientist   185000   USD  185000
# 7   2025          SE       FT  Data Scientist   148000   USD  148000
# 8   2025          MI       FT  Data Scientist   135000   USD  135000
# 9   2025          MI       FT  Data Scientist   108000   USD  108000
# 65  2025          SE       FT  Data Scientist   258000   USD  258000
#
#    residencia  remoto empresa tamanho_empresa senioridade_legivel
# 6          US       0      US               M              Sênior
# 7          US       0      US               M              Sênior
# 8          CA       0      CA               M               Pleno
# 9          CA       0      CA               M               Pleno
# 65         US       0      US               M              Sênior

# %%
import plotly.express as px

# Filtrar apenas os cientistas de dados
df_cientistas = df_limpo[df_limpo['cargo'] == 'Data Scientist']

# Agrupar por país e calcular média do salário
salario_por_pais = df_cientistas.groupby('residencia')['usd'].mean().reset_index()

# Ordenar do maior para o menor
salario_por_pais = salario_por_pais.sort_values(by='usd', ascending=False)

# %%
# Gráfico interativo de barras
# Criar um gráfico de barras com Plotly Express
fig = px.bar(
    salario_por_pais,             # DataFrame com os dados já agrupados por país
    x='residencia',               # Eixo X será o país (código de residência)
    y='usd',                      # Eixo Y será o salário médio em USD
    title='Média Salarial de Data Scientists por País',  # Título do gráfico
    labels={                      # Renomear os rótulos dos eixos
        'residencia': 'País',
        'usd': 'Salário Médio (USD)'
    }
)

# Exibir o gráfico interativo
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
